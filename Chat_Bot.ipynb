# %%
from google.colab import drive
drive.mount('/content/drive')
data_root= '/content/drive/My Drive/chatbot/intents.json'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_file=open(data_root,'r').read()
intents=json.loads(data_file)

# %%
# Data Preparation

words = []
classes = []
data_X = []
data_Y = []

for intent in intents['intents']:
    for pattern in intent['patterns']:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        data_X.append(tokens)
        data_Y.append(intent['tag'])

    if intent['tag'] not in classes:
        classes.append(intent['tag'])

lemmatizer = WordNetLemmatizer()
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words = sorted(set(words))

classes = sorted(set(classes))

print("Words:", words)
print("Classes:", classes)

training = []
out_empty = [0] * len(classes)

for idx, doc in enumerate(data_X):
    bow = []
    text = " ".join(doc)
    text = lemmatizer.lemmatize(text.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)

    output_row = list(out_empty)
    output_row[classes.index(data_Y[idx])] = 1

    training.append([bow, output_row])

random.shuffle(training)
training = np.array(training, dtype=object)

train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

print("Training X shape:", train_X.shape)
print("Training Y shape:", train_Y.shape)

# Neural Network

model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation='softmax'))
adam = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=200, verbose=1)

# Preprocessing the unit

def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word.lower()) for word in tokens]
    return tokens

def bag_of_words(text, vocab):
    tokens = clean_text(text)
    bow = [0] * len(vocab)
    for w in tokens:
        for idx, word in enumerate(vocab):
            if word == w:
                bow[idx] = 1
    return np.array(bow)

def pred_class(text, vocab, labels):
    bow = bag_of_words(text, vocab)
    result = model.predict(np.array([bow]))[0]
    thresh = 0.5
    y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
    y_pred.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in y_pred:
        return_list.append(labels[r[0]])
    print("Predicted classes:", return_list)  # Debugging print
    return return_list

def get_response(intents_list, intents_json):
    if len(intents_list) == 0:
        result = "Sorry! I didn't get that."
    else:
        tag = intents_list[0]
        list_of_intents = intents_json['intents']
        for i in list_of_intents:
            if i['tag'] == tag:
                result = random.choice(i['responses'])
                break
    return result

# Interaction with Chatbot

print("Press 0 if you don't want to chat with our chatbot")
while True:
    message = input("")
    if message == "0":
        break

    intents_list = pred_class(message, words, classes)
    result = get_response(intents_list, intents)
    print("Response:", result)
# Out:
# Words: ["'s", '2', 'a', 'afternoon', 'age', 'am', 'are', 'ask', 'bad', 'born', 'boy', 'bye', 'can', 'do', 'doing', 'feel', 'feeling', 'fine', 'girl', 'good', 'goodbye', 'great', 'hello', 'help', 'here', 'hi', 'how', 'i', 'is', 'job', 'live', 'me', 'men', 'minute', 'morning', 'much', 'no', 'old', 'please', 'sad', 'sec', 'still', 'thank', 'thanks', 'there', 'today', 'too', 'up', 'very', 'wait', 'were', 'what', 'when', 'where', 'woman', 'work', 'you', 'your']
# Classes: ['action', 'actions', 'age', 'bad', 'city', 'feeling', 'good', 'goodbye', 'hello', 'job', 'men', 'noanswer', 'still there', 'thanks', 'wait', 'women']
# Training X shape: (41, 58)
# Training Y shape: (41, 16)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               7552
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 16848 (65.81 KB)
# Trainable params: 16848 (65.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 2/2 [==============================] - 1s 9ms/step - loss: 2.7887 - accuracy: 0.0976
# Epoch 2/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.6939 - accuracy: 0.1707
# Epoch 3/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.5387 - accuracy: 0.3171
# Epoch 4/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.4062 - accuracy: 0.2439
# Epoch 5/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2258 - accuracy: 0.3659
# Epoch 6/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.3543 - accuracy: 0.2439
# Epoch 7/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9850 - accuracy: 0.3171
# Epoch 8/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8578 - accuracy: 0.3659
# Epoch 9/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8172 - accuracy: 0.4634
# Epoch 10/200
# 2/2 [==============================] - 0s 9ms/step - loss: 1.5609 - accuracy: 0.5610
# Epoch 11/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3505 - accuracy: 0.6341
# Epoch 12/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1672 - accuracy: 0.7073
# Epoch 13/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2306 - accuracy: 0.6098
# Epoch 14/200
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1319 - accuracy: 0.6341
# Epoch 15/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9856 - accuracy: 0.6829
# Epoch 16/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0374 - accuracy: 0.6585
# Epoch 17/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7769 - accuracy: 0.7073
# Epoch 18/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7370 - accuracy: 0.7317
# Epoch 19/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8949 - accuracy: 0.7073
# Epoch 20/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6521 - accuracy: 0.7805
# Epoch 21/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7293 - accuracy: 0.7805
# Epoch 22/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6629 - accuracy: 0.8049
# Epoch 23/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6361 - accuracy: 0.8293
# Epoch 24/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5895 - accuracy: 0.7805
# Epoch 25/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4955 - accuracy: 0.8293
# Epoch 26/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4991 - accuracy: 0.8293
# Epoch 27/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3891 - accuracy: 0.8293
# Epoch 28/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4877 - accuracy: 0.8537
# Epoch 29/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4368 - accuracy: 0.8537
# Epoch 30/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6162 - accuracy: 0.7805
# Epoch 31/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2663 - accuracy: 0.9268
# Epoch 32/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3908 - accuracy: 0.8780
# Epoch 33/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5110 - accuracy: 0.8780
# Epoch 34/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1540 - accuracy: 0.9512
# Epoch 35/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3282 - accuracy: 0.8537
# Epoch 36/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3828 - accuracy: 0.8049
# Epoch 37/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2980 - accuracy: 0.8293
# Epoch 38/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2138 - accuracy: 0.9756
# Epoch 39/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2620 - accuracy: 0.9268
# Epoch 40/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2592 - accuracy: 0.9268
# Epoch 41/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1916 - accuracy: 0.9512
# Epoch 42/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2471 - accuracy: 0.9512
# Epoch 43/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1563 - accuracy: 0.9268
# Epoch 44/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3858 - accuracy: 0.8293
# Epoch 45/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3341 - accuracy: 0.9024
# Epoch 46/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1769 - accuracy: 0.9756
# Epoch 47/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2846 - accuracy: 0.9024
# Epoch 48/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1613 - accuracy: 0.9512
# Epoch 49/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1600 - accuracy: 0.9756
# Epoch 50/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2525 - accuracy: 0.9024
# Epoch 51/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2168 - accuracy: 0.9268
# Epoch 52/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1613 - accuracy: 0.9512
# Epoch 53/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1625 - accuracy: 0.9268
# Epoch 54/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3868 - accuracy: 0.8537
# Epoch 55/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2498 - accuracy: 0.9268
# Epoch 56/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1184 - accuracy: 0.9756
# Epoch 57/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1577 - accuracy: 0.9756
# Epoch 58/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1069 - accuracy: 0.9756
# Epoch 59/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2915 - accuracy: 0.9024
# Epoch 60/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3297 - accuracy: 0.8780
# Epoch 61/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3634 - accuracy: 0.8780
# Epoch 62/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1186 - accuracy: 0.9512
# Epoch 63/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1970 - accuracy: 0.9512
# Epoch 64/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2340 - accuracy: 0.9268
# Epoch 65/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2118 - accuracy: 0.9024
# Epoch 66/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2498 - accuracy: 0.9268
# Epoch 67/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2301 - accuracy: 0.9268
# Epoch 68/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1507 - accuracy: 0.9756
# Epoch 69/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0977 - accuracy: 0.9756
# Epoch 70/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1889 - accuracy: 0.9512
# Epoch 71/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1440 - accuracy: 0.9512
# Epoch 72/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1767 - accuracy: 0.9756
# Epoch 73/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0867 - accuracy: 1.0000
# Epoch 74/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1670 - accuracy: 0.9268
# Epoch 75/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1476 - accuracy: 0.9512
# Epoch 76/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1912 - accuracy: 0.9268
# Epoch 77/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 78/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1722 - accuracy: 0.9268
# Epoch 79/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2363 - accuracy: 0.9268
# Epoch 80/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0920 - accuracy: 0.9756
# Epoch 81/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0894 - accuracy: 0.9756
# Epoch 82/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2923 - accuracy: 0.8780
# Epoch 83/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0879 - accuracy: 0.9512
# Epoch 84/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2049 - accuracy: 0.9268
# Epoch 85/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1330 - accuracy: 0.9756
# Epoch 86/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0963 - accuracy: 0.9756
# Epoch 87/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1906 - accuracy: 0.9268
# Epoch 88/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0502 - accuracy: 0.9756
# Epoch 89/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1446 - accuracy: 0.9268
# Epoch 90/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0672 - accuracy: 1.0000
# Epoch 91/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1144 - accuracy: 0.9512
# Epoch 92/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1956 - accuracy: 0.9024
# Epoch 93/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1665 - accuracy: 0.9024
# Epoch 94/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1700 - accuracy: 0.9268
# Epoch 95/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0736 - accuracy: 0.9756
# Epoch 96/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0907 - accuracy: 0.9756
# Epoch 97/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1188 - accuracy: 0.9268
# Epoch 98/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0976 - accuracy: 0.9512
# Epoch 99/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0928 - accuracy: 0.9512
# Epoch 100/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0463 - accuracy: 0.9756
# Epoch 101/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2189 - accuracy: 0.9268
# Epoch 102/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0795 - accuracy: 1.0000
# Epoch 103/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1377 - accuracy: 0.9512
# Epoch 104/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0770 - accuracy: 0.9756
# Epoch 105/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0577 - accuracy: 0.9756
# Epoch 106/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1919 - accuracy: 0.9512
# Epoch 107/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1523 - accuracy: 0.9268
# Epoch 108/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2007 - accuracy: 0.9024
# Epoch 109/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0886 - accuracy: 0.9756
# Epoch 110/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1472 - accuracy: 0.9512
# Epoch 111/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0922 - accuracy: 0.9512
# Epoch 112/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1087 - accuracy: 0.9756
# Epoch 113/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0430 - accuracy: 0.9756
# Epoch 114/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0976 - accuracy: 0.9756
# Epoch 115/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0971 - accuracy: 0.9512
# Epoch 116/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0769 - accuracy: 0.9756
# Epoch 117/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1320 - accuracy: 0.9512
# Epoch 118/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 119/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1333 - accuracy: 0.9268
# Epoch 120/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1360 - accuracy: 0.9512
# Epoch 121/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1213 - accuracy: 0.9512
# Epoch 122/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3099 - accuracy: 0.8780
# Epoch 123/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1441 - accuracy: 0.9268
# Epoch 124/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1751 - accuracy: 0.9512
# Epoch 125/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1123 - accuracy: 0.9512
# Epoch 126/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0798 - accuracy: 0.9756
# Epoch 127/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0804 - accuracy: 0.9756
# Epoch 128/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0552 - accuracy: 0.9756
# Epoch 129/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1426 - accuracy: 0.9512
# Epoch 130/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1390 - accuracy: 0.9512
# Epoch 131/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1163 - accuracy: 0.9268
# Epoch 132/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0684 - accuracy: 0.9756
# Epoch 133/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1258 - accuracy: 0.9268
# Epoch 134/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0668 - accuracy: 0.9756
# Epoch 135/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 136/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1567 - accuracy: 0.9268
# Epoch 137/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0656 - accuracy: 0.9756
# Epoch 138/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1439 - accuracy: 0.9512
# Epoch 139/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1228 - accuracy: 0.9756
# Epoch 140/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0654 - accuracy: 0.9756
# Epoch 141/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1825 - accuracy: 0.9512
# Epoch 142/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1171 - accuracy: 0.9512
# Epoch 143/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 144/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0589 - accuracy: 0.9756
# Epoch 145/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0828 - accuracy: 0.9756
# Epoch 146/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0295 - accuracy: 0.9756
# Epoch 147/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1065 - accuracy: 0.9756
# Epoch 148/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1334 - accuracy: 0.9268
# Epoch 149/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1084 - accuracy: 0.9512
# Epoch 150/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0852 - accuracy: 0.9512
# Epoch 151/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0487 - accuracy: 0.9756
# Epoch 152/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0701 - accuracy: 0.9756
# Epoch 153/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0578 - accuracy: 0.9756
# Epoch 154/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2346 - accuracy: 0.9268
# Epoch 155/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1282 - accuracy: 0.9512
# Epoch 156/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0647 - accuracy: 1.0000
# Epoch 157/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0809 - accuracy: 1.0000
# Epoch 158/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1042 - accuracy: 0.9756
# Epoch 159/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1205 - accuracy: 0.9268
# Epoch 160/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1210 - accuracy: 0.9512
# Epoch 161/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1102 - accuracy: 0.9756
# Epoch 162/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0807 - accuracy: 0.9268
# Epoch 163/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0573 - accuracy: 0.9756
# Epoch 164/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 165/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0356 - accuracy: 0.9756
# Epoch 166/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 167/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1188 - accuracy: 0.9268
# Epoch 168/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 169/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0766 - accuracy: 0.9512
# Epoch 170/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0500 - accuracy: 0.9756
# Epoch 171/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1350 - accuracy: 0.9512
# Epoch 172/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 173/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0726 - accuracy: 1.0000
# Epoch 174/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1286 - accuracy: 0.9024
# Epoch 175/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0677 - accuracy: 0.9756
# Epoch 176/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1317 - accuracy: 0.9512
# Epoch 177/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1191 - accuracy: 0.9512
# Epoch 178/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1673 - accuracy: 0.9024
# Epoch 179/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0622 - accuracy: 1.0000
# Epoch 180/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 181/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1150 - accuracy: 0.9756
# Epoch 182/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0517 - accuracy: 0.9756
# Epoch 183/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0637 - accuracy: 0.9756
# Epoch 184/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1643 - accuracy: 0.9268
# Epoch 185/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1248 - accuracy: 0.9756
# Epoch 186/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0577 - accuracy: 0.9756
# Epoch 187/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0657 - accuracy: 0.9756
# Epoch 188/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0733 - accuracy: 0.9512
# Epoch 189/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1460 - accuracy: 0.9512
# Epoch 190/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0499 - accuracy: 0.9756
# Epoch 191/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 192/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0589 - accuracy: 0.9756
# Epoch 193/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0800 - accuracy: 0.9512
# Epoch 194/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0663 - accuracy: 0.9756
# Epoch 195/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1314 - accuracy: 0.9512
# Epoch 196/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0544 - accuracy: 0.9512
# Epoch 198/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0513 - accuracy: 0.9756
# Epoch 199/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0645 - accuracy: 0.9512
# Epoch 200/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1877 - accuracy: 0.9268
# Press 0 if you don't want to chat with our chatbot
# hi
# 1/1 [==============================] - 0s 68ms/step
# Predicted classes: ['hello']
# Response: Hey!
# my name is x
# 1/1 [==============================] - 0s 21ms/step
# Predicted classes: ['job']
# Response: I work to serve you as well as possible
# how are you?
# 1/1 [==============================] - 0s 21ms/step
# Predicted classes: ['feeling']
# Response: I am feeling good, you?
# well
# 1/1 [==============================] - 0s 22ms/step
# Predicted classes: ['good']
# Response: So, everything's okay!
# yeah
# 1/1 [==============================] - 0s 20ms/step
# Predicted classes: ['good']
# Response: That is perfect!
# anything you want to share?
# 1/1 [==============================] - 0s 20ms/step
# Predicted classes: []
# Response: Sorry! I didn't get that.
# see ya
# 1/1 [==============================] - 0s 24ms/step
# Predicted classes: ['good']
# Response: That is perfect!
# bye
# 1/1 [==============================] - 0s 20ms/step
# Predicted classes: ['goodbye']
# Response: See you soon!
# 0
